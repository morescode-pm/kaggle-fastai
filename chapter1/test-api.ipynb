# %%
from gradio_client import Client, handle_file
from IPython.display import Image

image_file = 'test_images/Branta_canadensis.jpg'

client = Client("morescode-pm/urbanrivers-camtraps")
result = client.predict(
		image_path=handle_file(image_file),
		api_name="/top_3_preds"
)
display(Image(image_file, width=244))
print(result[0])
display(result[1])
# Out:
# Loaded as API: https://morescode-pm-urbanrivers-camtraps.hf.space ✔
# ### Prediction
# **Class**: Canada Goose
# **Probability**: 0.9998
#
# ### Top 3 Classes
# - Canada Goose: 0.9998
# - North American Beaver: 0.0002
# - Eastern Cottontail: 0.0000
# {'prediction': {'class': 'Branta_canadensis',
#   'common_name': 'Canada Goose',
#   'probability': 0.9998},
#  'top3': ['Canada Goose: 0.9998',
#   'North American Beaver: 0.0002',
#   'Eastern Cottontail: 0.0000']}
